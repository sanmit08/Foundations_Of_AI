# %%
from collections import deque
from queue import PriorityQueue

def calculate_distance(point1, point2, algorithm):
    x1, x2, y1, y2, z1, z2=  float(point1[0]), float(point2[0]), float(point1[1]), float(point2[1]), float(point1[2]), float(point2[2])
    if algorithm == 'A*':
        return ((x2 - x1)**2 + (y2 - y1)**2 + (z2- z1)**2)**0.5
    elif algorithm=='UCS':
        return ((x2 - x1)**2 + (y2 - y1)**2)**0.5

    return 1

def heuristic(current_node, goal):
    return calculate_distance(current_node, goal, 'A*')

def read_input_file(file_path):

    file =  open(file_path, "r")
    input_data = file.readlines()

    algorithm = input_data[0].strip('\n')
    energy_limit = int(input_data[1].strip('\n'))

    num_safe_locations = int(input_data[2][:-1])
    safe_locations = [i.strip('\n') for i in input_data[3:num_safe_locations+3]]
    safe_locations_dict = {}
    for i in safe_locations:
        safe_locations_dict[i.split(' ')[0]] = i.split(' ')[1:]

    num_safe_path_segments = int(input_data[num_safe_locations+3][:-1])
    safe_path_segments = [j.strip('\n') for j in input_data[num_safe_locations+4:]]
    graph = {}
    count=0
    for segment in safe_path_segments:
        node, neighbor = segment.split(' ')
        try:
            graph[node][neighbor] = calculate_distance(safe_locations_dict[node], safe_locations_dict[neighbor], algorithm)
        except:
            graph[node] = {}
            graph[node][neighbor] = calculate_distance(safe_locations_dict[node], safe_locations_dict[neighbor], algorithm)

        try:
            graph[neighbor][node] = calculate_distance(safe_locations_dict[node], safe_locations_dict[neighbor], algorithm)
        except:
            graph[neighbor] = {}
            graph[neighbor][node] = calculate_distance(safe_locations_dict[node], safe_locations_dict[neighbor], algorithm)

    return algorithm, energy_limit, safe_locations_dict, graph

def read_output_file(file_path):

  file =  open(file_path, "r")
  output_data = file.readlines()
  true_ans = []
  for line in output_data:
    for node in line.strip('\n').split(' '):
      true_ans.append(node)

  return true_ans[:-1]

def bfs_final(graph, start, goal, safe_locations_dict, motor_energy):
    queue = deque([(start, ['start'], 0)])
    visited = {}
    while queue:
        current_node, path, momentum = queue.popleft()
        if current_node==goal:
            return path
        if current_node in visited and visited[current_node]>=momentum:
            continue
        visited[current_node] = momentum
        for neighbor in graph[current_node]:
            z_node = safe_locations_dict[current_node][-1]
            z_neighbor = safe_locations_dict[neighbor][-1]
            energy_reqd = int(z_neighbor) - int(z_node)
            new_momentum = max(0,-energy_reqd)
            if neighbor not in visited or visited[neighbor]<new_momentum:
                if energy_reqd<=(motor_energy + momentum):
                    new_path = path + [neighbor]
                    queue.append((neighbor, new_path, new_momentum))
    return ['FAIL']

def ucs_final(graph, start, goal, safe_locations_dict, motor_energy):
    queue = PriorityQueue()
    queue.put((0, start, [start], 0))
    visited = {}
    while not queue.empty():
        cost, current_node, path, momentum = queue.get()
        if current_node==goal:
            return path, cost
        if current_node in visited and visited[current_node]>=momentum:
            continue
        visited[current_node] = momentum
        for neighbor, neighbor_cost in graph[current_node].items():
            z_node = safe_locations_dict[current_node][-1]
            z_neighbor = safe_locations_dict[neighbor][-1]
            energy_reqd = int(z_neighbor) - int(z_node)
            new_momentum = max(0,-energy_reqd)
            if neighbor not in visited or visited[neighbor]<new_momentum:
                if energy_reqd<=(motor_energy + momentum):
                    total_cost = cost + neighbor_cost
                    queue.put((total_cost, neighbor, path + [neighbor], new_momentum))
    return ['FAIL']

def a_star_final(graph, start, goal, safe_locations_dict, motor_energy):
    queue = PriorityQueue()
    queue.put((0, 0, start, [start], 0))
    visited = {}
    while not queue.empty():
        _, cost, current_node, path, momentum = queue.get()
        if current_node==goal:
            return path, cost
        if current_node in visited and visited[current_node]>=momentum:
            continue
        visited[current_node] = momentum
        for neighbor, neighbor_cost in graph[current_node].items():
            z_node = safe_locations_dict[current_node][-1]
            z_neighbor = safe_locations_dict[neighbor][-1]
            energy_reqd = int(z_neighbor) - int(z_node)
            new_momentum = max(0,-energy_reqd)
            if neighbor not in visited or visited[neighbor]<new_momentum:
                if energy_reqd<=(motor_energy + momentum):
                    cost_till_neighbor = cost + neighbor_cost
                    total_cost = cost_till_neighbor + heuristic(safe_locations_dict[neighbor], safe_locations_dict[goal])
                    queue.put((total_cost, cost_till_neighbor, neighbor, path + [neighbor], new_momentum))
    return ['FAIL']

# %%
import os
folder_path = '/content/drive/MyDrive/USC_CS_AI/CS561_AI/HW/HW1_Search/codes/testcases/'


for i in range(1,51):
    file_path = folder_path + 'input' + str(i) + '.txt'
    algorithm, motor_energy, safe_locations_dict, graph = read_input_file(file_path)

    print(i, 'File:', file_path.split('/')[-1])

    if algorithm=='BFS':
        print('BFS')
        ans = bfs_final(graph, 'start', 'goal', safe_locations_dict, motor_energy)
        print('My Answer:')
        print(len(ans), ans)

        output_file = folder_path + 'output' + str(i) + '.txt'
        true_ans = read_output_file(output_file)
        print('True Ans:')
        print(len(true_ans), true_ans)
        print()

    if algorithm=='UCS':
        print("UCS")
        ans = ucs_final(graph, 'start', 'goal', safe_locations_dict, motor_energy)
        print('My Answer:')
        print(len(ans[0]), ans)

        output_file = folder_path + 'output' + str(i) + '.txt'
        true_ans = read_output_file(output_file)
        print('True Ans:')
        print(len(true_ans), true_ans)
        output_length_file = folder_path + 'pathlen' + str(i) + '.txt'
        file =  open(output_length_file, "r")
        input_data = file.readlines()

        print('My paths cost:', round(ans[1], 2))
        print('True Paths cost:', input_data[0].strip('\n'))
        print()

    if algorithm=='A*':
        print('A*')
        ans = a_star_final(graph, 'start', 'goal', safe_locations_dict, motor_energy)
        print('My Answer:')
        print(len(ans[0]), ans)

        output_file = folder_path + 'output' + str(i) + '.txt'
        true_ans = read_output_file(output_file)
        print('True Ans:')
        print(len(true_ans), true_ans)
        output_length_file = folder_path + 'pathlen' + str(i) + '.txt'
        file =  open(output_length_file, "r")
        input_data = file.readlines()

        print('My paths cost:', round(ans[1], 2))
        print('True Paths cost:', input_data[0].strip('\n'))
        print()

    print()
# Out:
# 1 File: input1.txt
# BFS
# My Answer:
# 23 ['start', 'qdwa', 'wes', 'xwv', 'qk', 'pp', 'bcwz', 'kgi', 'bcwz', 'jknjn', 'vspp', 'sdru', 'qklo', 'zb', 'onbw', 'fnuj', 'xcf', 'hbzcw', 'fymx', 'dus', 'ube', 'ryo', 'goal']
# True Ans:
# 23 ['start', 'qdwa', 'wes', 'gpco', 'fmzr', 'eniu', 'hwghh', 'vdn', 'vry', 'dcd', 'efbk', 'jdcy', 'jnqzm', 'fxra', 'ivy', 'fxra', 'pgj', 'dytx', 'cwv', 'khz', 'ftv', 'hxouz', 'goal']
#
#
# 2 File: input2.txt
# UCS
# My Answer:
# 31 (['start', 'zl', 'qypez', 'zl', 'lnrf', 'zl', 'fenoa', 'sbcp', 'qed', 'ncbgo', 'ktmgl', 'ug', 'wns', 'nfw', 'eada', 'ta', 'djst', 'nyyvh', 'yscls', 'fm', 'uxe', 'mw', 'dtba', 'kgy', 'hza', 'cvuuk', 'uq', 'cvuuk', 'pikcv', 'myujd', 'goal'], 5877.934425231435)
# True Ans:
# 31 ['start', 'zl', 'qypez', 'zl', 'lnrf', 'zl', 'fenoa', 'sbcp', 'qed', 'ncbgo', 'ktmgl', 'ug', 'wns', 'nfw', 'eada', 'ta', 'djst', 'nyyvh', 'yscls', 'fm', 'uxe', 'mw', 'dtba', 'kgy', 'hza', 'cvuuk', 'uq', 'cvuuk', 'pikcv', 'myujd', 'goal']
# My paths cost: 5877.93
# True Paths cost: 5877.93
#
#
# 3 File: input3.txt
# UCS
# My Answer:
# 47 (['start', 'qgom', 'mxhd', 'fc', 'fdqm', 'dewzu', 'jdjf', 'aqe', 'gkub', 'qkib', 'ialvc', 'mfqe', 'einog', 'aaok', 'bp', 'xox', 'gk', 'bjslv', 'ty', 'bjhvj', 'wm', 'vgp', 'jxra', 'tmsj', 'ckap', 'fyk', 'rix', 'xrdym', 'ruutj', 'da', 'lucn', 'zrb', 'yrfdm', 'lkk', 'jik', 'cbhi', 'cet', 'fxx', 'akn', 'ksak', 'qltkq', 'nr', 'dbzp', 'dxar', 'kqjcu', 'hrkkg', 'goal'], 10296.109791478695)
# True Ans:
# 47 ['start', 'qgom', 'mxhd', 'fc', 'fdqm', 'dewzu', 'jdjf', 'aqe', 'gkub', 'qkib', 'ialvc', 'mfqe', 'einog', 'aaok', 'bp', 'xox', 'gk', 'bjslv', 'ty', 'bjhvj', 'wm', 'vgp', 'jxra', 'tmsj', 'ckap', 'fyk', 'rix', 'xrdym', 'ruutj', 'da', 'lucn', 'zrb', 'yrfdm', 'lkk', 'jik', 'cbhi', 'cet', 'fxx', 'akn', 'ksak', 'qltkq', 'nr', 'dbzp', 'dxar', 'kqjcu', 'hrkkg', 'goal']
# My paths cost: 10296.11
# True Paths cost: 10296.1
#
#
# 4 File: input4.txt
# BFS
# My Answer:
# 11 ['start', 'evo', 'bqwz', 'prb', 'hijey', 'cabhg', 'ng', 'gsh', 'aluqc', 'lfl', 'goal']
# True Ans:
# 11 ['start', 'evo', 'bqwz', 'shqc', 'hovt', 'ukans', 'in', 'dwgq', 'wqotx', 'lfl', 'goal']
#
#
# 5 File: input5.txt
# UCS
# My Answer:
# 23 (['start', 'vdfm', 'qhx', 'elt', 'mwbct', 'ysqf', 'maz', 'ggmuh', 'ybuc', 'ggmuh', 'kzd', 'ee', 'ttmzf', 'icci', 'zcv', 'oyava', 'anujl', 'czr', 'djc', 'pyc', 'mcvn', 'pyc', 'goal'], 4108.678063920304)
# True Ans:
# 23 ['start', 'vdfm', 'qhx', 'elt', 'mwbct', 'ysqf', 'maz', 'ggmuh', 'ybuc', 'ggmuh', 'kzd', 'ee', 'ttmzf', 'icci', 'zcv', 'oyava', 'anujl', 'czr', 'djc', 'pyc', 'mcvn', 'pyc', 'goal']
# My paths cost: 4108.68
# True Paths cost: 4108.68
#
#
# 6 File: input6.txt
# A*
# My Answer:
# 23 (['start', 'fogpf', 'loo', 'szz', 'ng', 'zud', 'qk', 'zud', 'be', 'colr', 'nru', 'tuk', 'sf', 'wpcnu', 'hw', 'dbq', 'vuv', 'dbq', 'udyw', 'zrpmj', 'hmf', 'ij', 'goal'], 3719.1973706321087)
# True Ans:
# 23 ['start', 'fogpf', 'loo', 'szz', 'ng', 'zud', 'qk', 'zud', 'be', 'colr', 'nru', 'tuk', 'sf', 'wpcnu', 'hw', 'dbq', 'vuv', 'dbq', 'udyw', 'zrpmj', 'hmf', 'ij', 'goal']
# My paths cost: 3719.2
# True Paths cost: 3719.2
#
#
# 7 File: input7.txt
# A*
# My Answer:
# 39 (['start', 'hfzxh', 'bpxm', 'hdqen', 'tekpv', 'dyyvj', 'rg', 'ala', 'uxy', 'vfve', 'hspre', 'rlzy', 'nu', 'qi', 'lmcgm', 'pdkv', 'cjv', 'ngv', 'ndo', 'hcq', 'onih', 'jh', 'frtj', 'dmcgx', 'sasod', 'ckrmi', 'clrz', 'rowbb', 'pvn', 'hpq', 'pvn', 'pmuj', 'iiues', 'eeotg', 'ezn', 'uru', 'zxen', 'xzom', 'goal'], 8144.6961703887755)
# True Ans:
# 39 ['start', 'hfzxh', 'bpxm', 'hdqen', 'tekpv', 'dyyvj', 'rg', 'ala', 'uxy', 'vfve', 'hspre', 'rlzy', 'nu', 'qi', 'lmcgm', 'pdkv', 'cjv', 'ngv', 'ndo', 'hcq', 'onih', 'jh', 'frtj', 'dmcgx', 'sasod', 'ckrmi', 'clrz', 'rowbb', 'pvn', 'hpq', 'pvn', 'pmuj', 'iiues', 'eeotg', 'ezn', 'uru', 'zxen', 'xzom', 'goal']
# My paths cost: 8144.7
# True Paths cost: 8144.7
#
#
# 8 File: input8.txt
# UCS
# My Answer:
# 24 (['start', 'renpv', 'ugek', 'yjho', 'wolm', 'hbfr', 'lpi', 'jls', 'noowi', 'uub', 'vh', 'adz', 'owf', 'spvto', 'vblbr', 'ce', 'jzv', 'dth', 'pipaj', 'mmud', 'djdpd', 'huln', 'sfvh', 'goal'], 3725.9662121059964)
# True Ans:
# 24 ['start', 'renpv', 'ugek', 'yjho', 'wolm', 'hbfr', 'lpi', 'jls', 'noowi', 'uub', 'vh', 'adz', 'owf', 'spvto', 'vblbr', 'ce', 'jzv', 'dth', 'pipaj', 'mmud', 'djdpd', 'huln', 'sfvh', 'goal']
# My paths cost: 3725.97
# True Paths cost: 3725.97
#
#
# 9 File: input9.txt
# A*
# My Answer:
# 24 (['start', 'zize', 'tpetn', 'zize', 'rpjex', 'dhvow', 'pdz', 'gjk', 'fjnx', 'fd', 'yvr', 'fd', 'vsu', 'fjhta', 'rr', 'ern', 'rr', 'apzd', 'vep', 'apzd', 'xdl', 'jw', 'cb', 'goal'], 5704.92535500013)
# True Ans:
# 24 ['start', 'zize', 'tpetn', 'zize', 'rpjex', 'dhvow', 'pdz', 'gjk', 'fjnx', 'fd', 'yvr', 'fd', 'vsu', 'fjhta', 'rr', 'ern', 'rr', 'apzd', 'vep', 'apzd', 'xdl', 'jw', 'cb', 'goal']
# My paths cost: 5704.93
# True Paths cost: 5704.93
#
#
# 10 File: input10.txt
# BFS
# My Answer:
# 9 ['start', 'rw', 'rnki', 'qs', 'hpnd', 'bo', 'dxih', 'grg', 'goal']
# True Ans:
# 9 ['start', 'rw', 'rnki', 'qs', 'hpnd', 'bo', 'dxih', 'grg', 'goal']
#
#
# 11 File: input11.txt
# A*
# My Answer:
# 41 (['start', 'cdtro', 'qhrq', 'qary', 'sz', 'pswx', 'xki', 'ge', 'okg', 'vwbkr', 'farb', 'pt', 'rgo', 'lpq', 'vwbkr', 'elz', 'abqh', 'ipek', 'qghv', 'ueih', 'ynsx', 'syoqg', 'zrz', 'xii', 'vxsnf', 'vdnmb', 'msd', 'rsth', 'uauy', 'gny', 'ahim', 'dqeup', 'xk', 'ns', 'ynafy', 'ectvc', 'mge', 'jlz', 'sy', 'pu', 'goal'], 10016.774409146468)
# True Ans:
# 41 ['start', 'cdtro', 'qhrq', 'qary', 'sz', 'pswx', 'xki', 'ge', 'okg', 'vwbkr', 'farb', 'pt', 'rgo', 'lpq', 'vwbkr', 'elz', 'abqh', 'ipek', 'qghv', 'ueih', 'ynsx', 'syoqg', 'zrz', 'xii', 'vxsnf', 'vdnmb', 'msd', 'rsth', 'uauy', 'gny', 'ahim', 'dqeup', 'xk', 'ns', 'ynafy', 'ectvc', 'mge', 'jlz', 'sy', 'pu', 'goal']
# My paths cost: 10016.77
# True Paths cost: 10016.8
#
#
# 12 File: input12.txt
# UCS
# My Answer:
# 39 (['start', 'pc', 'zugjw', 'sqbnd', 'jps', 'kg', 'qhio', 'afn', 'ytx', 'dank', 'jfv', 'zrn', 'start', 'agxhy', 'ugyu', 'ojyj', 'ndmbr', 'gvqa', 'ndmbr', 'fvwy', 'gplbw', 'wcaz', 'yyar', 'atafe', 'fomdt', 'mnpq', 'gplbw', 'ix', 'wipck', 'rx', 'lzlmf', 'xnul', 'lzlmf', 'qk', 'uwur', 'ob', 'omx', 'sasmm', 'goal'], 11270.077783100489)
# True Ans:
# 39 ['start', 'pc', 'zugjw', 'sqbnd', 'jps', 'kg', 'qhio', 'afn', 'ytx', 'dank', 'jfv', 'zrn', 'start', 'agxhy', 'ugyu', 'ojyj', 'ndmbr', 'gvqa', 'ndmbr', 'fvwy', 'gplbw', 'wcaz', 'yyar', 'atafe', 'fomdt', 'mnpq', 'gplbw', 'ix', 'wipck', 'rx', 'lzlmf', 'xnul', 'lzlmf', 'qk', 'uwur', 'ob', 'omx', 'sasmm', 'goal']
# My paths cost: 11270.08
# True Paths cost: 11270.1
#
#
# 13 File: input13.txt
# UCS
# My Answer:
# 14 (['start', 'itz', 'qxws', 'ebqwa', 'ebsdr', 'maiy', 'upojo', 'cmm', 'joz', 'leu', 'ee', 'lgh', 'ns', 'goal'], 2130.4648868260433)
# True Ans:
# 14 ['start', 'itz', 'qxws', 'ebqwa', 'ebsdr', 'maiy', 'upojo', 'cmm', 'joz', 'leu', 'ee', 'lgh', 'ns', 'goal']
# My paths cost: 2130.46
# True Paths cost: 2130.46
#
#
# 14 File: input14.txt
# A*
# My Answer:
# 15 (['start', 'wapui', 'ingi', 'xguk', 'nlbwn', 'emrgf', 'aagt', 'pivz', 'ezhk', 'las', 'tnnz', 'emyqx', 'tnnz', 'njxto', 'goal'], 5000.4865799871095)
# True Ans:
# 15 ['start', 'wapui', 'ingi', 'xguk', 'nlbwn', 'emrgf', 'aagt', 'pivz', 'ezhk', 'las', 'tnnz', 'emyqx', 'tnnz', 'njxto', 'goal']
# My paths cost: 5000.49
# True Paths cost: 5000.49
#
#
# 15 File: input15.txt
# UCS
# My Answer:
# 11 (['start', 'rr', 'cdv', 'ddyg', 'ns', 'fav', 'hs', 'kkg', 'cpfqm', 'fhysd', 'goal'], 2375.980153314952)
# True Ans:
# 11 ['start', 'rr', 'cdv', 'ddyg', 'ns', 'fav', 'hs', 'kkg', 'cpfqm', 'fhysd', 'goal']
# My paths cost: 2375.98
# True Paths cost: 2375.98
#
#
# 16 File: input16.txt
# A*
# My Answer:
# 84 (['start', 'pbuf', 'uxxnh', 'csqkz', 'vqoje', 'bfj', 'mw', 'bfj', 'goyc', 'bfj', 'lklat', 'ik', 'ovs', 'yxl', 'ipc', 'mtdd', 'vsls', 'eojor', 'ka', 'ygyn', 'slomf', 'sxgp', 'wlipr', 'trh', 'nvy', 'hvkvc', 'wam', 'uznz', 'ihowp', 'aofmw', 'py', 'uzl', 'uhvjo', 'rxkvc', 'vtrik', 'wjmfn', 'mzzh', 'aw', 'tvv', 'uis', 'czwlm', 'elg', 'mbgb', 'yys', 'asjtl', 'bsqqm', 'xntbv', 'bsqqm', 'kqx', 'ssork', 'kr', 'wvkd', 'pi', 'wvkd', 'cpbt', 'tcqn', 'mqi', 'qrfl', 'vcmja', 'ypy', 'dzax', 'koczm', 'krbq', 'ql', 'ruvh', 'wim', 'jobb', 'kwv', 'vnr', 'sppy', 'vpgx', 'lljjx', 'wma', 'rch', 'kqkw', 'jkey', 'htikk', 'mwp', 'ycybd', 'duzbd', 'xwsq', 'jonsd', 'gkboz', 'goal'], 20188.534337521007)
# True Ans:
# 84 ['start', 'pbuf', 'uxxnh', 'csqkz', 'vqoje', 'bfj', 'mw', 'bfj', 'goyc', 'bfj', 'lklat', 'ik', 'ovs', 'yxl', 'ipc', 'mtdd', 'vsls', 'eojor', 'ka', 'ygyn', 'slomf', 'sxgp', 'wlipr', 'trh', 'nvy', 'hvkvc', 'wam', 'uznz', 'ihowp', 'aofmw', 'py', 'uzl', 'uhvjo', 'rxkvc', 'vtrik', 'wjmfn', 'mzzh', 'aw', 'tvv', 'uis', 'czwlm', 'elg', 'mbgb', 'yys', 'asjtl', 'bsqqm', 'xntbv', 'bsqqm', 'kqx', 'ssork', 'kr', 'wvkd', 'pi', 'wvkd', 'cpbt', 'tcqn', 'mqi', 'qrfl', 'vcmja', 'ypy', 'dzax', 'koczm', 'krbq', 'ql', 'ruvh', 'wim', 'jobb', 'kwv', 'vnr', 'sppy', 'vpgx', 'lljjx', 'wma', 'rch', 'kqkw', 'jkey', 'htikk', 'mwp', 'ycybd', 'duzbd', 'xwsq', 'jonsd', 'gkboz', 'goal']
# My paths cost: 20188.53
# True Paths cost: 20188.5
#
#
# 17 File: input17.txt
# BFS
# My Answer:
# 32 ['start', 'zbdqo', 'rtoh', 'nz', 'onpc', 'yz', 'hwgf', 'cchvy', 'xq', 'ptkj', 'hwbk', 'ptkj', 'yek', 'uixn', 'jupbm', 'noaq', 'vaewa', 'zgq', 'rjg', 'dcoz', 'yek', 'vq', 'qgxz', 'semhl', 'py', 'qkwv', 'gvnaq', 'ahid', 'qiod', 'pio', 'fcbm', 'goal']
# True Ans:
# 32 ['start', 'zbdqo', 'rtoh', 'nz', 'onpc', 'yz', 'hwgf', 'cchvy', 'xq', 'ptkj', 'reaz', 'ptkj', 'yek', 'uixn', 'jupbm', 'noaq', 'vaewa', 'zgq', 'rjg', 'dcoz', 'yek', 'vq', 'qgxz', 'semhl', 'py', 'qkwv', 'gvnaq', 'ahid', 'qiod', 'pio', 'fcbm', 'goal']
#
#
# 18 File: input18.txt
# BFS
# My Answer:
# 20 ['start', 'kguzr', 'yj', 'pkl', 'edmjz', 'cuvkr', 'rxskk', 'rxzpk', 'yy', 'lni', 'flb', 'bujbc', 'nc', 'yblc', 'nc', 'ldbzl', 'nyk', 'ux', 'ixb', 'goal']
# True Ans:
# 20 ['start', 'kguzr', 'yj', 'pkl', 'kuj', 'whutb', 'gjvw', 'rxzpk', 'yy', 'lni', 'flb', 'bujbc', 'nc', 'yblc', 'nc', 'ldbzl', 'nyk', 'ux', 'ixb', 'goal']
#
#
# 19 File: input19.txt
# UCS
# My Answer:
# 24 (['start', 'vtdkc', 'oxo', 'zl', 'bcqay', 'gprw', 'qfdty', 'qksme', 'dboc', 'asepn', 'osg', 'ket', 'tso', 'dmm', 'iqff', 'ozw', 'tnq', 'hki', 'dawb', 'ic', 'lvyjf', 'kujxh', 'iao', 'goal'], 4420.8347086499125)
# True Ans:
# 24 ['start', 'vtdkc', 'oxo', 'zl', 'bcqay', 'gprw', 'qfdty', 'qksme', 'dboc', 'asepn', 'osg', 'ket', 'tso', 'dmm', 'iqff', 'ozw', 'tnq', 'hki', 'dawb', 'ic', 'lvyjf', 'kujxh', 'iao', 'goal']
# My paths cost: 4420.83
# True Paths cost: 4420.83
#
#
# 20 File: input20.txt
# A*
# My Answer:
# 18 (['start', 'zl', 'start', 'vuuu', 'uw', 'adgb', 'txieg', 'xqk', 'su', 'pixv', 'su', 'vtlv', 'djz', 'ztst', 'apuu', 'hyin', 'miyi', 'goal'], 4043.0510539314155)
# True Ans:
# 18 ['start', 'zl', 'start', 'vuuu', 'uw', 'adgb', 'txieg', 'xqk', 'su', 'pixv', 'su', 'vtlv', 'djz', 'ztst', 'apuu', 'hyin', 'miyi', 'goal']
# My paths cost: 4043.05
# True Paths cost: 4043.05
#
#
# 21 File: input21.txt
# A*
# My Answer:
# 40 (['start', 'vjm', 'yleuo', 'fw', 'uwjt', 'cmyc', 'fmwhm', 'cmnl', 'dycl', 'fgg', 'niiri', 'dpenx', 'wampr', 'shwf', 'hpfk', 'fgg', 'gtspz', 'rxpa', 'irx', 'njv', 'og', 'qeqdz', 'dhvyd', 'cpv', 'ccsti', 'vjc', 'nieeg', 'gjko', 'nieeg', 'xrwk', 'uikfq', 'hq', 'cmeoy', 'khd', 'txi', 'xrdr', 'qkly', 'fjni', 'dllv', 'goal'], 7025.227735071698)
# True Ans:
# 40 ['start', 'vjm', 'yleuo', 'fw', 'uwjt', 'cmyc', 'fmwhm', 'cmnl', 'dycl', 'fgg', 'niiri', 'dpenx', 'wampr', 'shwf', 'hpfk', 'fgg', 'gtspz', 'rxpa', 'irx', 'njv', 'og', 'qeqdz', 'dhvyd', 'cpv', 'ccsti', 'vjc', 'nieeg', 'gjko', 'nieeg', 'xrwk', 'uikfq', 'hq', 'cmeoy', 'khd', 'txi', 'xrdr', 'qkly', 'fjni', 'dllv', 'goal']
# My paths cost: 7025.23
# True Paths cost: 7025.23
#
#
# 22 File: input22.txt
# BFS
# My Answer:
# 35 ['start', 'znh', 'huwh', 'lwqy', 'ibry', 'umnqk', 'owecy', 'umnqk', 'kdzse', 'ccxsw', 'nwe', 'cbe', 'smrs', 'goi', 'smrs', 'ausia', 'el', 'votgi', 'rqmrc', 'zgiuv', 'wvm', 'cbe', 'mdak', 'cbe', 'rnbij', 'ibry', 'iwgen', 'ie', 'kazv', 'mnp', 'zkt', 'uy', 'pvplm', 'yr', 'goal']
# True Ans:
# 35 ['start', 'znh', 'huwh', 'lwqy', 'ibry', 'umnqk', 'owecy', 'umnqk', 'kdzse', 'ccxsw', 'nwe', 'cbe', 'smrs', 'goi', 'smrs', 'ausia', 'el', 'jwz', 'rqmrc', 'zgiuv', 'wvm', 'cbe', 'mdak', 'cbe', 'rnbij', 'ibry', 'iwgen', 'ie', 'wzqty', 'mnp', 'zkt', 'uy', 'pvplm', 'yr', 'goal']
#
#
# 23 File: input23.txt
# UCS
# My Answer:
# 13 (['start', 'dtprg', 'qy', 'imk', 'ta', 'adntz', 'caxfd', 'imph', 'xbajy', 'imph', 'sdc', 'nx', 'goal'], 2386.6282578178907)
# True Ans:
# 13 ['start', 'dtprg', 'qy', 'imk', 'ta', 'adntz', 'caxfd', 'imph', 'xbajy', 'imph', 'sdc', 'nx', 'goal']
# My paths cost: 2386.63
# True Paths cost: 2386.63
#
#
# 24 File: input24.txt
# UCS
# My Answer:
# 22 (['start', 'sjis', 'jv', 'ivt', 'qly', 'whqv', 'qwb', 'wzo', 'iqhq', 'gzjl', 'mm', 'oub', 'sy', 'nes', 'tgtpq', 'uuvo', 'attbi', 'kklge', 'gngg', 'vxsn', 'qpws', 'goal'], 3262.8937220840785)
# True Ans:
# 22 ['start', 'sjis', 'jv', 'ivt', 'qly', 'whqv', 'qwb', 'wzo', 'iqhq', 'gzjl', 'mm', 'oub', 'sy', 'nes', 'tgtpq', 'uuvo', 'attbi', 'kklge', 'gngg', 'vxsn', 'qpws', 'goal']
# My paths cost: 3262.89
# True Paths cost: 3262.89
#
#
# 25 File: input25.txt
# UCS
# My Answer:
# 25 (['start', 'vy', 'kr', 'vnazy', 'kr', 'ukgtk', 'kr', 'wqv', 'vepxo', 'zxk', 'cohjh', 'qrc', 'usl', 'egniu', 'uj', 'fffr', 'lqt', 'qj', 'eccis', 'qj', 'gqffs', 'zgjts', 'fe', 'wyc', 'goal'], 6384.919240796934)
# True Ans:
# 25 ['start', 'vy', 'kr', 'vnazy', 'kr', 'ukgtk', 'kr', 'wqv', 'vepxo', 'zxk', 'cohjh', 'qrc', 'usl', 'egniu', 'uj', 'fffr', 'lqt', 'qj', 'eccis', 'qj', 'gqffs', 'zgjts', 'fe', 'wyc', 'goal']
# My paths cost: 6384.92
# True Paths cost: 6384.92
#
#
# 26 File: input26.txt
# UCS
# My Answer:
# 42 (['start', 'zfs', 'ezgaj', 'oxdjx', 'bzl', 'xk', 'cw', 'jwrv', 'cnzp', 'jwrv', 'thuu', 'av', 'wk', 'oy', 'bolmr', 'cdjbp', 'rpkx', 'ait', 'hp', 'aom', 'kanom', 'rpmy', 'omet', 'rc', 'txz', 'xgle', 'donny', 'uyorg', 'drk', 'vrlhq', 'dxft', 'ipgo', 'tipxf', 'ptuen', 'bp', 'wnzsy', 'mcr', 'gmf', 'pk', 'lswc', 'ijo', 'goal'], 7869.981491966924)
# True Ans:
# 42 ['start', 'zfs', 'ezgaj', 'oxdjx', 'bzl', 'xk', 'cw', 'jwrv', 'cnzp', 'jwrv', 'thuu', 'av', 'wk', 'oy', 'bolmr', 'cdjbp', 'rpkx', 'ait', 'hp', 'aom', 'kanom', 'rpmy', 'omet', 'rc', 'txz', 'xgle', 'donny', 'uyorg', 'drk', 'vrlhq', 'dxft', 'ipgo', 'tipxf', 'ptuen', 'bp', 'wnzsy', 'mcr', 'gmf', 'pk', 'lswc', 'ijo', 'goal']
# My paths cost: 7869.98
# True Paths cost: 7869.98
#
#
# 27 File: input27.txt
# A*
# My Answer:
# 8 (['start', 'imcnw', 'qvug', 'qtcao', 'wmycr', 'bvshi', 'utmz', 'goal'], 2777.531940206316)
# True Ans:
# 8 ['start', 'imcnw', 'qvug', 'qtcao', 'wmycr', 'bvshi', 'utmz', 'goal']
# My paths cost: 2777.53
# True Paths cost: 2777.53
#
#
# 28 File: input28.txt
# A*
# My Answer:
# 22 (['start', 'gsr', 'qdi', 'gsr', 'jol', 'ykim', 'jol', 'gjskz', 'lnp', 'ndet', 'egof', 'wjloy', 'egof', 'plat', 'ndet', 'uabj', 'ae', 'yfwa', 'bkfaa', 'whyv', 'cwt', 'goal'], 5212.540738389542)
# True Ans:
# 22 ['start', 'gsr', 'qdi', 'gsr', 'jol', 'ykim', 'jol', 'gjskz', 'lnp', 'ndet', 'egof', 'wjloy', 'egof', 'plat', 'ndet', 'uabj', 'ae', 'yfwa', 'bkfaa', 'whyv', 'cwt', 'goal']
# My paths cost: 5212.54
# True Paths cost: 5212.54
#
#
# 29 File: input29.txt
# UCS
# My Answer:
# 22 (['start', 'ywx', 'cx', 'jkoa', 'jgze', 'pq', 'piln', 'erm', 'mmcha', 'gw', 'hyapo', 'dmequ', 'hcn', 'xugp', 'kdas', 'tlotm', 'eni', 'fxr', 'eni', 'wj', 'eh', 'goal'], 2650.415033018454)
# True Ans:
# 22 ['start', 'ywx', 'cx', 'jkoa', 'jgze', 'pq', 'piln', 'erm', 'mmcha', 'gw', 'hyapo', 'dmequ', 'hcn', 'xugp', 'kdas', 'tlotm', 'eni', 'fxr', 'eni', 'wj', 'eh', 'goal']
# My paths cost: 2650.42
# True Paths cost: 2650.42
#
#
# 30 File: input30.txt
# A*
# My Answer:
# 32 (['start', 'fyrfo', 'lbkzc', 'esp', 'zqnj', 'ifryf', 'mx', 'ojde', 'smpog', 'yktr', 'fqbl', 'yktr', 'nx', 'dtou', 'nx', 'ajufy', 'rjh', 'ncens', 'cdtxn', 'jtvns', 'rla', 'osv', 'escl', 'ff', 'bb', 'dnq', 'xcsd', 'hddvi', 'jbyx', 'rd', 'iwwv', 'goal'], 7946.5876994571945)
# True Ans:
# 32 ['start', 'fyrfo', 'lbkzc', 'esp', 'zqnj', 'ifryf', 'mx', 'ojde', 'smpog', 'yktr', 'fqbl', 'yktr', 'nx', 'dtou', 'nx', 'ajufy', 'rjh', 'ncens', 'cdtxn', 'jtvns', 'rla', 'osv', 'escl', 'ff', 'bb', 'dnq', 'xcsd', 'hddvi', 'jbyx', 'rd', 'iwwv', 'goal']
# My paths cost: 7946.59
# True Paths cost: 7946.59
#
#
# 31 File: input31.txt
# A*
# My Answer:
# 18 (['start', 'lkbe', 'jdqp', 'ends', 'smm', 'nhqy', 'hgfdh', 'dceu', 'nhi', 'htfze', 'em', 'wyy', 'faex', 'wyy', 'ob', 'php', 'tvg', 'goal'], 4645.830465647036)
# True Ans:
# 18 ['start', 'lkbe', 'jdqp', 'ends', 'smm', 'nhqy', 'hgfdh', 'dceu', 'nhi', 'htfze', 'em', 'wyy', 'faex', 'wyy', 'ob', 'php', 'tvg', 'goal']
# My paths cost: 4645.83
# True Paths cost: 4645.83
#
#
# 32 File: input32.txt
# A*
# My Answer:
# 24 (['start', 'flrc', 'fxp', 'lbylb', 'qwsbt', 'crx', 'tuif', 'ttmol', 'uxnkx', 'xhmwq', 'hczf', 'jlet', 'wm', 'rmzvz', 'pez', 'esr', 'itlwx', 'fho', 'mnlki', 'ljhtr', 'slc', 'vjeo', 'qeoia', 'goal'], 5744.732455030734)
# True Ans:
# 24 ['start', 'flrc', 'fxp', 'lbylb', 'qwsbt', 'crx', 'tuif', 'ttmol', 'uxnkx', 'xhmwq', 'hczf', 'jlet', 'wm', 'rmzvz', 'pez', 'esr', 'itlwx', 'fho', 'mnlki', 'ljhtr', 'slc', 'vjeo', 'qeoia', 'goal']
# My paths cost: 5744.73
# True Paths cost: 5744.73
#
#
# 33 File: input33.txt
# BFS
# My Answer:
# 32 ['start', 'wmgg', 'duzy', 'vlk', 'kpc', 'mlfdd', 'sapx', 'naxde', 'ua', 'grfah', 'cdjq', 'fmieb', 'jey', 'hebb', 'lyl', 'ifdpc', 'pqxf', 'vlk', 'liudu', 'wqty', 'qsrwc', 'fw', 'qsrwc', 'udqiq', 'lcjxo', 'ewhcj', 'qswwh', 'tbw', 'dssg', 'jijtn', 'jojzk', 'goal']
# True Ans:
# 32 ['start', 'ersl', 'maqhl', 'czjh', 'uh', 'wh', 'uvvw', 'xlqvi', 'oqni', 'xz', 'hcnfo', 'aqs', 'aphew', 'udsi', 'ojmb', 'wbpq', 'szkip', 'mhz', 'szkip', 'mljoi', 'zh', 'llh', 'yie', 'ld', 'zvszc', 'ewhcj', 'qswwh', 'tbw', 'dssg', 'jijtn', 'jojzk', 'goal']
#
#
# 34 File: input34.txt
# A*
# My Answer:
# 37 (['start', 'rzuau', 'yh', 'esi', 'sgnbu', 'jxx', 'ifpo', 'xd', 'jihe', 'xd', 'juwk', 'jm', 'ltmk', 'jue', 'ooyb', 'jue', 'zoi', 'lwuj', 'cs', 'kmzns', 'pye', 'yl', 'urlv', 'allvc', 'iyyx', 'allvc', 'yty', 'ex', 'yty', 'rjuze', 'jsqu', 'now', 'ywpgg', 'ijs', 'ri', 'bvsh', 'goal'], 9784.71643924752)
# True Ans:
# 37 ['start', 'rzuau', 'yh', 'esi', 'sgnbu', 'jxx', 'ifpo', 'xd', 'jihe', 'xd', 'juwk', 'jm', 'ltmk', 'jue', 'ooyb', 'jue', 'zoi', 'lwuj', 'cs', 'kmzns', 'pye', 'yl', 'urlv', 'allvc', 'iyyx', 'allvc', 'yty', 'ex', 'yty', 'rjuze', 'jsqu', 'now', 'ywpgg', 'ijs', 'ri', 'bvsh', 'goal']
# My paths cost: 9784.72
# True Paths cost: 9784.72
#
#
# 35 File: input35.txt
# A*
# My Answer:
# 16 (['start', 'bkvj', 'qaus', 'ilee', 'oehde', 'kli', 'xfwqi', 'tlyza', 'wie', 'izot', 'juc', 'gi', 'lauze', 'pop', 'lauze', 'goal'], 3759.971373628892)
# True Ans:
# 16 ['start', 'bkvj', 'qaus', 'ilee', 'oehde', 'kli', 'xfwqi', 'tlyza', 'wie', 'izot', 'juc', 'gi', 'lauze', 'pop', 'lauze', 'goal']
# My paths cost: 3759.97
# True Paths cost: 3759.97
#
#
# 36 File: input36.txt
# BFS
# My Answer:
# 15 ['start', 'ajbb', 'hke', 'qpqmc', 'zsyd', 'sgjgp', 'xfa', 'ko', 'av', 'dxq', 'qml', 'snjr', 'idsf', 'qtblj', 'goal']
# True Ans:
# 15 ['start', 'vk', 'kwj', 'pt', 'twe', 'rra', 'krb', 'vo', 'wvldy', 'ag', 'pjjii', 'uhmvb', 'gntjk', 'rftwu', 'goal']
#
#
# 37 File: input37.txt
# UCS
# My Answer:
# 37 (['start', 'eksfe', 'yzoa', 'eksfe', 'abon', 'yvmp', 'oxkwc', 'gnhj', 'orhc', 'qbfof', 'dnniw', 'fd', 'kehc', 'udbps', 'et', 'bowoz', 'ocsq', 'has', 'gp', 'lx', 'tdua', 'bkoh', 'gvus', 'rhjpn', 'sngyj', 'bzm', 'nzz', 'rcs', 'otq', 'rj', 'anktp', 'mw', 'ov', 'surtp', 'ipt', 'efn', 'goal'], 4711.862424798329)
# True Ans:
# 37 ['start', 'eksfe', 'yzoa', 'eksfe', 'abon', 'yvmp', 'oxkwc', 'gnhj', 'orhc', 'qbfof', 'dnniw', 'fd', 'kehc', 'udbps', 'et', 'bowoz', 'ocsq', 'has', 'gp', 'lx', 'tdua', 'bkoh', 'gvus', 'rhjpn', 'sngyj', 'bzm', 'nzz', 'rcs', 'otq', 'rj', 'anktp', 'mw', 'ov', 'surtp', 'ipt', 'efn', 'goal']
# My paths cost: 4711.86
# True Paths cost: 4711.86
#
#
# 38 File: input38.txt
# BFS
# My Answer:
# 25 ['start', 'yqqq', 'ojp', 'goxd', 'ibhq', 'efdiv', 'tuqd', 'dvz', 'pnsj', 'gsvx', 'nvg', 'mt', 'qjvh', 'cu', 'mhmuk', 'ti', 'mhmuk', 'etuw', 'wxbqp', 'iy', 'ajoj', 'jn', 'gyjoi', 'yikdx', 'goal']
# True Ans:
# 25 ['start', 'yqqq', 'ojp', 'goxd', 'ibhq', 'efdiv', 'tuqd', 'dvz', 'pnsj', 'gsvx', 'nvg', 'mt', 'qjvh', 'cu', 'mhmuk', 'ti', 'mhmuk', 'etuw', 'mhmuk', 'xw', 'mhmuk', 'sjulr', 'wxbqp', 'yikdx', 'goal']
#
#
# 39 File: input39.txt
# UCS
# My Answer:
# 27 (['start', 'efx', 'uvrt', 'avy', 'iuki', 'uvxv', 'txw', 'cjky', 'txw', 'kdv', 'ytsm', 'oh', 'jmuk', 'jy', 'sbfp', 'zgr', 'ilhqh', 'gr', 'vsjb', 'fp', 'qxc', 'dh', 'jou', 'kbv', 'ksi', 'occuz', 'goal'], 5353.6866226814445)
# True Ans:
# 27 ['start', 'efx', 'uvrt', 'avy', 'iuki', 'uvxv', 'txw', 'cjky', 'txw', 'kdv', 'ytsm', 'oh', 'jmuk', 'jy', 'sbfp', 'zgr', 'ilhqh', 'gr', 'vsjb', 'fp', 'qxc', 'dh', 'jou', 'kbv', 'ksi', 'occuz', 'goal']
# My paths cost: 5353.69
# True Paths cost: 5353.69
#
#
# 40 File: input40.txt
# BFS
# My Answer:
# 14 ['start', 'dtbl', 'bpp', 'mlbp', 'okr', 'uidjt', 'rln', 'ftvm', 'gqx', 'dc', 'pgcx', 'xaejl', 'cwzb', 'goal']
# True Ans:
# 14 ['start', 'dtbl', 'bpp', 'uknpw', 'zjpx', 'dz', 'yeir', 'emwg', 'ukyyi', 'paqx', 'pgcx', 'xaejl', 'cwzb', 'goal']
#
#
# 41 File: input41.txt
# UCS
# My Answer:
# 58 (['start', 'awu', 'jnwin', 'hullm', 'buio', 'fwjf', 'bfo', 'my', 'qus', 'uwxm', 'oo', 'mzlr', 'jqtg', 'dkybr', 'rikei', 'my', 'iqlwp', 'vgnjw', 'we', 'vuxh', 'mkl', 'ak', 'yibgc', 'vha', 'nuij', 'sopbx', 'seuje', 'vrx', 'jgzd', 'tobad', 'dqazq', 'qz', 'fjfuc', 'yymw', 'vdoed', 'car', 'ki', 'xtocx', 'xkes', 'yw', 'qb', 'dbf', 'nyo', 'qat', 'db', 'vxmph', 'jgaf', 'rvvrp', 'aspoj', 'iidmf', 'ldjqq', 'vx', 'qsot', 'mi', 'kbss', 'vpgow', 'hzlbj', 'goal'], 16077.892973608488)
# True Ans:
# 58 ['start', 'awu', 'jnwin', 'hullm', 'buio', 'fwjf', 'bfo', 'my', 'qus', 'uwxm', 'oo', 'mzlr', 'jqtg', 'dkybr', 'rikei', 'my', 'iqlwp', 'vgnjw', 'we', 'vuxh', 'mkl', 'ak', 'yibgc', 'vha', 'nuij', 'sopbx', 'seuje', 'vrx', 'jgzd', 'tobad', 'dqazq', 'qz', 'fjfuc', 'yymw', 'vdoed', 'car', 'ki', 'xtocx', 'xkes', 'yw', 'qb', 'dbf', 'nyo', 'qat', 'db', 'vxmph', 'jgaf', 'rvvrp', 'aspoj', 'iidmf', 'ldjqq', 'vx', 'qsot', 'mi', 'kbss', 'vpgow', 'hzlbj', 'goal']
# My paths cost: 16077.89
# True Paths cost: 16077.9
#
#
# 42 File: input42.txt
# UCS
# My Answer:
# 21 (['start', 'wjqe', 'bm', 'rtxrm', 'iiyi', 'ed', 'pd', 'icwel', 'emez', 'gnsf', 'jmhk', 'icqh', 'tmfh', 'zdl', 'ijw', 'cs', 'fhec', 'pvz', 'exiex', 'lwfp', 'goal'], 5656.352961888262)
# True Ans:
# 21 ['start', 'wjqe', 'bm', 'rtxrm', 'iiyi', 'ed', 'pd', 'icwel', 'emez', 'gnsf', 'jmhk', 'icqh', 'tmfh', 'zdl', 'ijw', 'cs', 'fhec', 'pvz', 'exiex', 'lwfp', 'goal']
# My paths cost: 5656.35
# True Paths cost: 5656.35
#
#
# 43 File: input43.txt
# A*
# My Answer:
# 47 (['start', 'nkbbw', 'vlm', 'liehs', 'ksau', 'fbet', 'alln', 'nrb', 'wq', 'gmc', 'okeme', 'gmc', 'wl', 'vnwbu', 'cfeby', 'zve', 'ksau', 'wb', 'zbtgy', 'fiais', 'wh', 'afc', 'wh', 'fs', 'bmsud', 'vosu', 'gzxz', 'oe', 'jvtbt', 'oe', 'qqjr', 'fxwg', 'spxc', 'yorut', 'qb', 'im', 'xhkcf', 'liyu', 'uss', 'xpy', 'axgbk', 'bt', 'wz', 'xevfk', 'uwltd', 'xopgd', 'goal'], 8657.503724358025)
# True Ans:
# 47 ['start', 'nkbbw', 'vlm', 'liehs', 'ksau', 'fbet', 'alln', 'nrb', 'wq', 'gmc', 'okeme', 'gmc', 'wl', 'vnwbu', 'cfeby', 'zve', 'ksau', 'wb', 'zbtgy', 'fiais', 'wh', 'afc', 'wh', 'fs', 'bmsud', 'vosu', 'gzxz', 'oe', 'jvtbt', 'oe', 'qqjr', 'fxwg', 'spxc', 'yorut', 'qb', 'im', 'xhkcf', 'liyu', 'uss', 'xpy', 'axgbk', 'bt', 'wz', 'xevfk', 'uwltd', 'xopgd', 'goal']
# My paths cost: 8657.5
# True Paths cost: 8657.5
#
#
# 44 File: input44.txt
# UCS
# My Answer:
# 15 (['start', 'bvsuc', 'zzcoi', 'wxz', 'el', 'nn', 'qowfx', 'anamo', 'brzla', 'zgm', 'zqzqk', 'lavkj', 'den', 'fgl', 'goal'], 3023.2755434977403)
# True Ans:
# 15 ['start', 'bvsuc', 'zzcoi', 'wxz', 'el', 'nn', 'qowfx', 'anamo', 'brzla', 'zgm', 'zqzqk', 'lavkj', 'den', 'fgl', 'goal']
# My paths cost: 3023.28
# True Paths cost: 3023.28
#
#
# 45 File: input45.txt
# BFS
# My Answer:
# 15 ['start', 'xurs', 'zld', 'qgz', 'pda', 'cw', 'yhuyu', 'uwci', 'aogw', 'uwci', 'nhsx', 'bro', 'nij', 'ekqav', 'goal']
# True Ans:
# 15 ['start', 'xurs', 'zld', 'qgz', 'deul', 'qgz', 'fzvcy', 'nbi', 'zl', 'vuybj', 'rhg', 'kieys', 'hks', 'nfoe', 'goal']
#
#
# 46 File: input46.txt
# A*
# My Answer:
# 28 (['start', 'nhb', 'xvcfn', 'ncze', 'df', 'xydtu', 'acasv', 'kvedj', 'bzqrb', 'gsw', 'ykpz', 'et', 'lfcm', 'zha', 'isje', 'msyby', 'jyb', 'cxq', 'yh', 'kb', 'uswmh', 'zuz', 'thue', 'egkil', 'thue', 'eeuw', 'ollz', 'goal'], 5147.172539159006)
# True Ans:
# 28 ['start', 'nhb', 'xvcfn', 'ncze', 'df', 'xydtu', 'acasv', 'kvedj', 'bzqrb', 'gsw', 'ykpz', 'et', 'lfcm', 'zha', 'isje', 'msyby', 'jyb', 'cxq', 'yh', 'kb', 'uswmh', 'zuz', 'thue', 'egkil', 'thue', 'eeuw', 'ollz', 'goal']
# My paths cost: 5147.17
# True Paths cost: 5147.17
#
#
# 47 File: input47.txt
# A*
# My Answer:
# 36 (['start', 'qww', 'wtunc', 'nelcu', 'urljq', 'nelcu', 'cg', 'jqera', 'xc', 'dqxms', 'lklw', 'nvvth', 'edy', 'gj', 'edy', 'yn', 'iux', 'szvdf', 'fn', 'lpul', 'mfw', 'kn', 'uvzm', 'yhsz', 'mqqfb', 'uql', 'mqqfb', 'ham', 'fziil', 'renm', 'hfyed', 'lidub', 'na', 'vbqd', 'wuyxf', 'goal'], 7466.672141675613)
# True Ans:
# 36 ['start', 'qww', 'wtunc', 'nelcu', 'urljq', 'nelcu', 'cg', 'jqera', 'xc', 'dqxms', 'lklw', 'nvvth', 'edy', 'gj', 'edy', 'yn', 'iux', 'szvdf', 'fn', 'lpul', 'mfw', 'kn', 'uvzm', 'yhsz', 'mqqfb', 'uql', 'mqqfb', 'ham', 'fziil', 'renm', 'hfyed', 'lidub', 'na', 'vbqd', 'wuyxf', 'goal']
# My paths cost: 7466.67
# True Paths cost: 7466.67
#
#
# 48 File: input48.txt
# BFS
# My Answer:
# 39 ['start', 'mjbxn', 'zcben', 'tnc', 'rbnfi', 'un', 'dfpf', 'kpamq', 'wh', 'oniv', 'ub', 'nxaw', 'jq', 'pqv', 'qfrd', 'fwnb', 'ilaag', 'hivd', 'fwu', 'smfdm', 'we', 'bzfm', 'rcfq', 'dxf', 'idz', 'dxf', 'inme', 'ww', 'pwee', 'cdhnc', 'mhl', 'skymo', 'nkrm', 'slei', 'tatqy', 'iepc', 'bq', 'vmo', 'goal']
# True Ans:
# 39 ['start', 'mjbxn', 'zcben', 'tnc', 'zog', 'yfur', 'pbnj', 'ygmzd', 'wh', 'oniv', 'ub', 'nxaw', 'jq', 'pqv', 'qfrd', 'fwnb', 'ilaag', 'hivd', 'fwu', 'smfdm', 'we', 'bzfm', 'rcfq', 'dxf', 'idz', 'dxf', 'inme', 'ww', 'pwee', 'cdhnc', 'mhl', 'skymo', 'nkrm', 'slei', 'tatqy', 'iepc', 'bq', 'vmo', 'goal']
#
#
# 49 File: input49.txt
# UCS
# My Answer:
# 15 (['start', 'bxqct', 'koz', 'akxxs', 'qb', 'znc', 'gc', 'xze', 'pioah', 'mwyz', 'rn', 'bsd', 'xduiq', 'hg', 'goal'], 3481.31499795092)
# True Ans:
# 15 ['start', 'bxqct', 'koz', 'akxxs', 'qb', 'znc', 'gc', 'xze', 'pioah', 'mwyz', 'rn', 'bsd', 'xduiq', 'hg', 'goal']
# My paths cost: 3481.31
# True Paths cost: 3481.31
#
#
# 50 File: input50.txt
# A*
# My Answer:
# 54 (['start', 'qrfel', 'gqnfv', 'lunxw', 'ceza', 'fvne', 'ceza', 'eknv', 'xtqwk', 'rhkt', 'ab', 'wfpk', 'clw', 'wfpk', 'cuno', 'fmgm', 'rn', 'omw', 'tpul', 'fqcd', 'nrcb', 'dlg', 'dn', 'mks', 'ocd', 'ht', 'kkjo', 'xmcg', 'hmztt', 'rz', 'vwpik', 'ovbtk', 'udjz', 'hxout', 'orkrb', 'lfuwa', 'oswmt', 'lfuwa', 'toabw', 'lfuwa', 'ykdp', 'dmvn', 'tfs', 'qii', 'diomm', 'cdew', 'abtx', 'svik', 'ap', 'kg', 'ap', 'wtik', 'mxywt', 'goal'], 11772.551320529788)
# True Ans:
# 54 ['start', 'qrfel', 'gqnfv', 'lunxw', 'ceza', 'fvne', 'ceza', 'eknv', 'xtqwk', 'rhkt', 'ab', 'wfpk', 'clw', 'wfpk', 'cuno', 'fmgm', 'rn', 'omw', 'tpul', 'fqcd', 'nrcb', 'dlg', 'dn', 'mks', 'ocd', 'ht', 'kkjo', 'xmcg', 'hmztt', 'rz', 'vwpik', 'ovbtk', 'udjz', 'hxout', 'orkrb', 'lfuwa', 'oswmt', 'lfuwa', 'toabw', 'lfuwa', 'ykdp', 'dmvn', 'tfs', 'qii', 'diomm', 'cdew', 'abtx', 'svik', 'ap', 'kg', 'ap', 'wtik', 'mxywt', 'goal']
# My paths cost: 11772.55
# True Paths cost: 11772.6
